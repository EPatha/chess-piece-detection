# %% [markdown]
# <a href="https://colab.research.google.com/github/EPatha/chess-vision-for-blind/blob/main/Chess_Detection1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Libraries

# %%
# !pip install python-chess
# !pip install pyttsx3
# !pip install ultralytics
# !pip install opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2
import chess
import chess.svg
import numpy as np
import pandas as pd
import pickle
import tensorflow as tf
from skimage.metrics import structural_similarity as ssim
from matplotlib import pyplot as plt
import pyttsx3
import threading

# %%
model = YOLO('yolov8n.pt')

# %% [markdown]
# ### Option 1: Mount Google Drive and load model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load your trained YOLOv8 model
model = YOLO('/content/drive/MyDrive/TA-Ephesians-Prismaranatha_A11.2022.14632/chess_detect')
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.

# %%
# Load your trained YOLOv8 model (after direct upload)
model = YOLO('/content/best.pt')

# %% [markdown]
# #📊 ANALISIS PERFORMA MODEL
#
# #Metrik Utama:
# ✅ mAP50: 0.9879 (98.79%)
#
# #✅ Precision: ~0.98 (98%)
#    (sangat sedikit false positives)
#
# #✅ Recall: ~0.99 (99%)
#    (hampir tidak ada yang terlewat)
#
# #⚠️ mAP50-95: 0.4632 (46.32%)
#    Artinya: Pada IoU threshold yang sangat ketat (50-95%), performa turun
#    Ini NORMAL karena:
#    - Chess pieces kecil dan mirip satu sama lain
#    - YOLOv8n (nano) bukan model terbesar
#    - Dataset relatif kecil (606 images)
#
# #KESIMPULAN:
# 🎯 Model SUDAH SANGAT BAGUS untuk production!
#    - mAP50 98.79% = TOP TIER performance
#    - Precision & Recall tinggi = reliable detection
#    - Cocok untuk real-time detection
#
# #💡 Bisa di-improve jika:
#    - Pakai model lebih besar (YOLOv8s/m/l) → mAP50-95 naik
#    - Tambah data training → lebih robust
#    - Fine-tune hyperparameters → sedikit better
