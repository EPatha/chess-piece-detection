# %% [markdown]
# <a href="https://colab.research.google.com/github/EPatha/chess-vision-for-blind/blob/Colab/Chess_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Libraries

# %%
# !pip install python-chess
# !pip install pyttsx3

# %%
import cv2
import chess
import chess.svg
import numpy as np
import pandas as pd
import pickle
import tensorflow as tf
from skimage.metrics import structural_similarity as ssim
from matplotlib import pyplot as plt
import pyttsx3
import threading
